pt_kuhn4 = [0.9258411957949715, 0.8829411007428993, 0.842064654542477, 0.7777344858982596, 0.6978687299872173, 0.6632880101466452, 0.6146642384489465, 0.5669753514529705, 0.5276179843035482, 0.497612374868075, 0.4786289492075931, 0.4706355513968079, 0.45723609742837557, 0.44823262999774727, 0.4493859574296621, 0.44673817530843574, 0.4490684232961919, 0.45122844255102584, 0.4619192802047743, 0.4649005918727618]
pt_kuhn5 = [0.9117420066336805, 0.7940201644225783, 0.7288770716970222, 0.6910837244776069, 0.6371336078693635, 0.5907259362084191, 0.5574534220973357, 0.535207538216038, 0.5255008743026045, 0.5212872126513359, 0.5251768393628992, 0.5195450900686065, 0.5142098394847641, 0.5130339942029863, 0.5081925707640036, 0.5081132336912204, 0.502744607793246, 0.5031543143834853, 0.5098682246087921, 0.5149615066565998]

# %%
x = [i for i in range(len(tf_kuhn1))] + [i for i in range(len(tf_kuhn4))] + [i for i in range(len(tf_kuhn5))]
y = tf_kuhn1 + tf_kuhn4 + tf_kuhn5
sns.lineplot(x, y, label='TnsorFlow')

x_p = [i for i in range(len(pt_kuhn2))] + [i for i in range(len(pt_kuhn4))] + [i for i in range(len(pt_kuhn5))]
y_p = pt_kuhn2 + pt_kuhn4 + pt_kuhn5
sns.lineplot(x_p, y_p, label='PyTorch')

plt.title('Kuhn Poker')
plt.xlabel('Epsodes(in thousand)')
plt.ylabel('Nash Conv')
# Out:
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Nash Conv')

# %%
tf_leduc1 = [4.740922223170062, 4.793398491303164, 4.788179639299509, 4.779825750106534, 4.670174114495279, 4.685091329399376, 4.584213660948533, 4.8129643877532144, 4.884091899447599, 5.093095749786861]
tf_leduc2 = [4.67023444680699, 4.736713353462143, 4.787689609314793, 4.767934295112731, 4.88426813123383, 4.87908982331984, 4.800293529139065, 4.763680454650778, 4.806311970259916, 5.141696616685925]
tf_leduc3 = [4.862916167026951, 5.137871834271525, 5.251775999975575, 5.015061063635537, 5.045564089698065, 5.130410734799045, 5.1641989847930265, 5.076391682238295, 5.030817490207582, 4.795625265062855]
tf_leduc4 = [4.720580705953815, 4.749483997465015, 4.762153759840439, 4.614934653791604, 4.694948923098359, 4.58856208386835, 4.500648809481751, 4.36771227475684, 4.4433707451544375, 4.453912521985062]

pt_leduc1 = [4.816378315359527, 5.183435771931083, 4.981805847350352, 4.959138290012623, 4.987403549910527, 4.894065221510903, 5.087053143228525, 5.001063352058948, 4.574781550661821, 4.45628410467555]
pt_leduc2 = [4.762049732195072, 5.220065921048683, 5.434335654150852, 5.148536129794721, 4.927764855547408, 4.880683280302989, 4.770471931455553, 4.908578138855047, 4.944229230221213, 4.990821043836672]
pt_leduc3 = [4.738434718539721, 4.740359240222743, 4.715566360673841, 4.695352025473474, 4.673802467801391, 4.673510013744725, 4.674157125854695, 4.724951769213946, 4.7457643793637425, 4.743087811560461]

# %%
x = [i for i in range(len(tf_leduc1))] * 3
y = tf_leduc1 + tf_leduc3 + tf_leduc4
sns.lineplot(x, y, label='TnsorFlow')

x_p = [i for i in range(len(pt_leduc1))]*3
y_p = pt_leduc1 + pt_leduc2 + pt_leduc3
sns.lineplot(x_p, y_p, label='PyTorch')

plt.title('Leduc Poker')
plt.xlabel('Epsodes(in thousand)')
plt.ylabel('Nash Conv')
# Out:
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Nash Conv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tf_kuhn1 = [0.37634222852969845, 0.3329617142446238, 0.316304184769198, 0.3045667251147599, 0.2996968567236956, 0.29648718139785263, 0.2925400219064348, 0.28970398339261194, 0.2875417698455125, 0.28551046108017847]
tf_kuhn2 = [0.3508181140581246, 0.32352316749210963, 0.316259592287224, 0.31217058792542457, 0.30881532799910527, 0.3057851190472687, 0.30298410939552933, 0.3012667532562806, 0.2987812815076813, 0.2962932557235479]
tf_kuhn3 = [0.37900984807950605, 0.32177749715166226, 0.2988562104484438, 0.29518197830443826, 0.2915205565020096, 0.2893561715284406, 0.28679159436437335, 0.2845466054763692, 0.281548425862029, 0.2785872204966148]


pt_kuhn1 = [0.3865144533825705, 0.33816569008275504, 0.30352580158285275, 0.2941192446058414, 0.2878639222945156, 0.2856887248891349, 0.2820757910358165, 0.2810582591831773, 0.27925652706102727, 0.2768920242272239]
pt_kuhn2 = [0.3620111648885066, 0.31271177510954773, 0.29973228050132517, 0.29117547732525173, 0.2869790826510561, 0.2802378814424329, 0.27519049690420605, 0.2703495365791758, 0.26785184518091587, 0.26297236263585877]
pt_kuhn3 = [0.37092262871931947, 0.3322919479007246, 0.32598084961811824, 0.3201311578162632, 0.31529660391506154, 0.3109706414241214, 0.30676118328072066, 0.30358706281042247, 0.30025006487761985, 0.2973322909669257]

# %%
x = [i * 10 for i in range(len(tf_kuhn1))] * 3
y = tf_kuhn1 + tf_kuhn2 + tf_kuhn3
sns.lineplot(x, y, label='TnsorFlow')

x_p = [i * 10 for i in range(len(pt_kuhn1))] * 3
y_p = pt_kuhn1 + pt_kuhn2 + pt_kuhn3
sns.lineplot(x_p, y_p, label='PyTorch')

plt.title('Kuhn Poker')
plt.xlabel('Epsodes(in thousands)')
plt.ylabel('Exploitability')
# Out:
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Exploitability')

# %%
tf_leduc1 = [2.29522031853187, 2.232513408758911, 2.2022675584609854, 2.159063877316146, 2.092788764417209, 2.07994362503557, 2.0129441511015447, 1.944155974041941, 1.8977937272444136, 1.9062401925227301]
tf_leduc2 = [2.166085455338493, 2.1943027108585005, 2.1458993495018595, 2.0748712709266046, 2.0358769311833687, 2.019741514788876, 1.966971920509333, 1.9305169110361222, 1.8728848526073336, 1.8900982527973893]
tf_leduc3 = [2.2392726266077894, 2.239777544707624, 2.2255411968226078, 2.1410972362134126, 2.115922933413102, 2.05420737023231, 1.98743257776856, 2.024815840747584, 1.911366473818718, 1.8708556764754363]
tf_leduc4 = [2.595945624369934, 2.3978561096544, 2.2754552938515595, 2.292387165236848, 2.161305849638241, 2.1529491120985345, 2.066636061867233, 2.05650548975179, 2.0750003303561826, 2.029161603889028]
tf_leduc5 = [2.369499491805596, 2.1855354212742903, 2.2028650242181054, 2.1622182114165285, 2.165994703512826, 2.0638300353853447, 1.9897424780808475, 1.9876378261285481, 1.936542564309626, 1.820292484546954]


pt_leduc1 = [2.367885783277425, 2.2979566706409127, 2.2741196171801716, 2.1848434714601606, 2.2558293301227534, 2.135094930512871, 2.1466879926309383, 2.052469578659454, 1.9430717063665897, 1.885844054485296]
pt_leduc2 = [2.4172849822474243, 2.4017001800034814, 2.302650819608085, 2.224801226361323, 2.150999699764391, 2.1748179852950824, 2.1585482982211897, 2.049305431722529, 1.958255019884994, 1.9695148018302493]
pt_leduc3 = [2.2749961873716575, 2.2666778677428434, 2.165287145100697, 2.079457954314968, 2.0918588635337105, 2.044400192524746, 2.027876559334195, 2.030867540135744, 1.9833670682156674, 1.9716290231472917]
pt_leduc4 = [2.2145492130950784, 2.1373351079906295, 2.1402202167504245, 2.1780810582849908, 2.0549493290473118, 2.0663108221192696, 2.007294744892595, 1.913486012680631, 1.9452607731626874, 1.8692626557938719]
pt_leduc5 = [2.5407027568810427, 2.4192188835878694, 2.3870904835765687, 2.3705128244737397, 2.37103139407428, 2.3825592925303614, 2.2912773913589364, 2.14614239071165, 2.1098058047302484, 2.122468933162436]

# %%
x = [i * 10 for i in range(len(tf_leduc1))] * 4
y = tf_leduc1  + tf_leduc3 + tf_leduc4 + tf_leduc5
sns.lineplot(x, y, label='TnsorFlow')

x_p = [i * 10 for i in range(len(pt_leduc1))] * 4
y_p = pt_leduc1 + pt_leduc2 + pt_leduc3 + pt_leduc4
sns.lineplot(x_p, y_p, label='PyTorch')

plt.title('Leduc Poker')
plt.xlabel('Epsodes(in thousand)')
plt.ylabel('Exploitability')
# Out:
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Exploitability')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tf_a2c1 = [-0.46, -0.58, -0.54, -0.62, -0.66, -0.44, -0.66, -0.56, -0.48, -0.6, -0.4, -0.4, -0.54, -0.48, -0.48, -0.44, -0.68, -0.6, -0.46, -0.7, -0.66, -0.54, -0.64, -0.58, -0.7, -0.64, -0.5, -0.6, -0.7, -0.54, -0.48, -0.54, -0.64, -0.64, -0.4, -0.74, -0.58, -0.58, -0.52, -0.44, -0.56, -0.7, -0.48, -0.6, -0.38, -0.68, -0.62, -0.6, -0.62, -0.62, -0.64, -0.56, -0.52, -0.56, -0.64, -0.6, -0.48, -0.74, -0.68]
tf_a2c2 = [-0.54, -0.66, -0.62, -0.52, -0.6, -0.52, -0.6, -0.56, -0.6, -0.5, -0.42, -0.46, -0.56, -0.56, -0.48, -0.62, -0.46, -0.6, -0.64, -0.5, -0.5, -0.6, -0.46, -0.72, -0.6, -0.46, -0.56, -0.7, -0.64, -0.64, -0.72, -0.64, -0.58, -0.36, -0.52, -0.48, -0.62, -0.7, -0.56, -0.78, -0.7, -0.6, -0.68, -0.58, -0.56, -0.58, -0.7, -0.54, -0.5, -0.7, -0.58, -0.58, -0.48, -0.38, -0.48, -0.5, -0.62, -0.58, -0.54]
pt_a2c3 = [-0.66, -0.54, -0.52, -0.4, -0.32, -0.58, -0.58, -0.48, -0.58, -0.62, -0.54, -0.54, -0.5, -0.74, -0.5, -0.62, -0.6, -0.62, -0.58, -0.5, -0.58, -0.66, -0.36, -0.64, -0.52, -0.66, -0.5, -0.5, -0.4, -0.5, -0.38, -0.44, -0.54, -0.66, -0.44, -0.54, -0.68, -0.62, -0.52, -0.56, -0.4, -0.6, -0.52, -0.42, -0.52, -0.64, -0.46, -0.48, -0.6, -0.54, -0.7, -0.72, -0.68, -0.5, -0.66, -0.62, -0.48, -0.56, -0.62]

# %%
x = [i * 50 for i in range(len(tf_a2c1))] * 3
y = tf_a2c1  + tf_a2c2 + tf_a2c3
sns.lineplot(x, y, label='TnsorFlow:A2C')

x_d = [i * 50 for i in range(len(tf_dqn1))] * 3
y_d = tf_dqn1 + tf_dqn2 + tf_dqn3
sns.lineplot(x_d, y_d, label='TnsorFlow:DQN')

#x_p = [i * 50 for i in range(len(pt_a2c1))] * 3
#y_p = pt_a2c1  + pt_a2c2 + pt_a2c3
#sns.lineplot(x_p, y_p, label='PyTorch:A2C')

plt.title('Catch')
plt.xlabel('Epsodes')
plt.ylabel('Avg Return')
# Out:
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Avg Return')

# %%
x = [i * 50 for i in range(len(tf_a2c1))] * 3
y = tf_a2c1  + tf_a2c2 + tf_a2c3
sns.lineplot(x, y, label='TnsorFlow:A2C')

#x_d = [i * 50 for i in range(len(tf_dqn1))] * 3
#y_d = tf_dqn1 + tf_dqn2 + tf_dqn3
#sns.lineplot(x_d, y_d, label='TnsorFlow:DQN')

x_p = [i * 50 for i in range(len(pt_a2c1))] * 3
y_p = pt_a2c1  + pt_a2c2 + pt_a2c3
sns.lineplot(x_p, y_p, label='PyTorch:A2C')

plt.title('Catch')
plt.xlabel('Epsodes')
plt.ylabel('Avg Return')
# Out:
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Avg Return')

# %% [markdown]
# # Large Episodes

# %%
tf_a2c1 = [-0.58, -0.62, -0.48, -0.58, -0.6, -0.62, -0.68, -0.58, -0.56, -0.48, -0.58, -0.48, -0.42, -0.56, -0.6, -0.5, -0.5, -0.48, -0.58, -0.48, -0.58, -0.5, -0.46, -0.5, -0.28, -0.66, -0.54, -0.52, -0.6, -0.66, -0.62, -0.44, -0.5, -0.36, -0.58, -0.68, -0.5, -0.46, -0.58, -0.46, -0.36, -0.6, -0.6, -0.68, -0.38, -0.56, -0.64, -0.66, -0.48, -0.58, -0.4, -0.56, -0.56, -0.5, -0.56, -0.54, -0.54, -0.48, -0.5, -0.6, -0.34, -0.52, -0.52, -0.52, -0.68, -0.44, -0.56, -0.54, -0.46, -0.56, -0.52, -0.58, -0.6, -0.44, -0.64, -0.46, -0.44, -0.54, -0.64, -0.5, -0.46, -0.56, -0.42, -0.48, -0.6, -0.6, -0.52, -0.62, -0.48, -0.48, -0.62, -0.44, -0.42, -0.38, -0.5, -0.38, -0.68, -0.5, -0.48]
0.6, -0.56, -0.66, -0.62, -0.38, -0.48, -0.4, -0.58, -0.54, -0.44, -0.46, -0.52, -0.6, -0.58, -0.6, -0.48, -0.54, -0.58, -0.52, -0.62, -0.56, -0.34, -0.48, -0.58, -0.6, -0.6, -0.54, -0.46, -0.66, -0.44, -0.52, -0.6, -0.56, -0.48, -0.54, -0.5, -0.44, -0.58, -0.46, -0.48, -0.52, -0.66, -0.32, -0.38, -0.36, -0.42, -0.48, -0.52, -0.44, -0.34, -0.56, -0.4, -0.48, -0.5, -0.4, -0.68, -0.44, -0.5, -0.54, -0.48, -0.52]
pt_a2c3 = [-0.5, -0.58, -0.58, -0.42, -0.54, -0.48, -0.56, -0.64, -0.58, -0.6, -0.62, -0.64, -0.6, -0.58, -0.56, -0.56, -0.52, -0.64, -0.4, -0.48, -0.56, -0.58, -0.4, -0.54, -0.58, -0.52, -0.56, -0.62, -0.64, -0.56, -0.46, -0.5, -0.54, -0.38, -0.5, -0.52, -0.58, -0.68, -0.58, -0.44, -0.52, -0.58, -0.56, -0.7, -0.44, -0.54, -0.48, -0.48, -0.44, -0.46, -0.5, -0.56, -0.6, -0.58, -0.6, -0.52, -0.56, -0.54, -0.56, -0.58, -0.5, -0.34, -0.46, -0.64, -0.62, -0.5, -0.42, -0.42, -0.44, -0.5, -0.44, -0.36, -0.46, -0.42, -0.48, -0.62, -0.46, -0.34, -0.52, -0.62, -0.46, -0.5, -0.52, -0.44, -0.5, -0.52, -0.66, -0.48, -0.6, -0.62, -0.56, -0.48, -0.48, -0.44, -0.52, -0.6, -0.56, -0.44, -0.46]

# %%
x = [i  for i in range(len(tf_a2c1))] * 3
y = tf_a2c1  + tf_a2c2 + tf_a2c3
sns.lineplot(x, y, label='TnsorFlow:A2C')

x_d = [i  for i in range(len(tf_dqn1))] * 3
y_d = tf_dqn1 + tf_dqn2 + tf_dqn3
sns.lineplot(x_d, y_d, label='TnsorFlow:DQN')

#x_p = [i for i in range(len(pt_a2c1))] * 3
#y_p = pt_a2c1  + pt_a2c2 + pt_a2c3
#sns.lineplot(x_p, y_p, label='PyTorch:A2C')

plt.title('Catch')
plt.xlabel('Epsodes(in thousands)')
plt.ylabel('Avg Return')
plt.show()
# Out:
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x = [i for i in range(len(tf_a2c1))] * 3
y = tf_a2c1  + tf_a2c2 + tf_a2c3
sns.lineplot(x, y, label='TnsorFlow:A2C')

#x_d = [i * 50 for i in range(len(tf_dqn1))] * 3
#y_d = tf_dqn1 + tf_dqn2 + tf_dqn3
#sns.lineplot(x_d, y_d, label='TnsorFlow:DQN')

x_p = [i for i in range(len(pt_a2c1))] * 3
y_p = pt_a2c1  + pt_a2c2 + pt_a2c3
sns.lineplot(x_p, y_p, label='PyTorch:A2C')

plt.title('Catch')
plt.xlabel('Epsodes(in thousands)')
plt.ylabel('Avg Return')
plt.show()
# Out:
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #
.4, -0.04, -0.1, -0.26, -0.32, -0.28, -0.18, -0.36, -0.26, -0.1, -0.42, -0.22, -0.16, -0.12, -0.14, -0.28, -0.1, -0.08, -0.06, 0.0, 0.1, 0.02, 0.0, 0.04, 0.12, 0.06, 0.18, 0.12, 0.1, 0.34, 0.22, 0.2, 0.28, 0.22, 0.16, 0.04, 0.14, 0.28, 0.42, 0.42, 0.44, 0.4, 0.54]
pt_a2c2 = [-0.62, -0.48, -0.36, -0.56, -0.6, -0.6, -0.56, -0.5, -0.56, -0.56, -0.4, -0.26, -0.46, -0.5, -0.44, -0.5, -0.52, -0.38, -0.54, -0.5, -0.44, -0.56, -0.46, -0.3, -0.54, -0.48, -0.4, -0.42, -0.52, -0.46, -0.48, -0.5, -0.58, -0.38, -0.54, -0.38, -0.42, -0.46, -0.38, -0.4, -0.32, -0.38, -0.34, -0.44, -0.34, -0.38, -0.36, -0.24, -0.18, -0.18, -0.2, -0.18, -0.24, -0.24, -0.28, -0.18, -0.12, -0.3, -0.18, -0.2, -0.22, -0.06, -0.2, 0.08, 0.16, -0.02, 0.12, 0.28, 0.28, 0.08, 0.16, 0.28, 0.28, 0.28, 0.3, 0.3, 0.16, 0.24, 0.4, 0.24, 0.34, 0.36, 0.44, 0.54, 0.5, 0.54, 0.62, 0.52, 0.52, 0.48, 0.54, 0.56, 0.54, 0.56, 0.68, 0.68, 0.68, 0.68, 0.72]
pt_a2c3 = [-0.4, -0.56, -0.58, -0.46, -0.6, -0.54, -0.6, -0.46, -0.56, -0.46, -0.48, -0.32, -0.62, -0.48, -0.5, -0.32, -0.58, -0.44, -0.56, -0.34, -0.52, -0.58, -0.48, -0.6, -0.38, -0.5, -0.38, -0.3, -0.58, -0.52, -0.46, -0.3, -0.42, -0.36, -0.46, -0.46, -0.58, -0.4, -0.32, -0.46, -0.24, -0.66, -0.28, -0.38, -0.3, -0.4, -0.44, -0.46, -0.42, -0.38, -0.52, -0.34, -0.28, -0.14, -0.4, -0.2, -0.28, 0.0, -0.14, -0.34, -0.1, -0.14, -0.02, -0.24, -0.16, 0.18, -0.16, -0.02, 0.08, 0.1, 0.18, 0.18, -0.1, 0.22, 0.28, 0.1, 0.22, 0.22, 0.36, 0.16, 0.36, 0.4, 0.46, 0.56, 0.36, 0.34, 0.3, 0.44, 0.42, 0.54, 0.5, 0.68, 0.58, 0.74, 0.64, 0.66, 0.64, 0.74, 0.76]

# %%
x = [i  for i in range(len(tf_a2c1))] * 3
y = tf_a2c1  + tf_a2c2 + tf_a2c3
sns.lineplot(x, y, label='TnsorFlow:A2C')

x_d = [i  for i in range(len(tf_dqn1))] * 3
y_d = tf_dqn1 + tf_dqn2 + tf_dqn3
sns.lineplot(x_d, y_d, label='TnsorFlow:DQN')

x_p = [i for i in range(len(pt_a2c1))] * 3
y_p = pt_a2c1  + pt_a2c2 + pt_a2c3
sns.lineplot(x_p, y_p, label='PyTorch:A2C')

plt.title('Catch')
plt.xlabel('Epsodes(in thousands)')
plt.ylabel('Avg Return')
plt.show()
# Out:
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/sugawara/.pyenv/versions/3.7.3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...
