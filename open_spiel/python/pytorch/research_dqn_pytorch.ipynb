# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from absl import app
from absl import flags
from absl import logging
import numpy as np
import tensorflow.compat.v1 as tf

from open_spiel.python import rl_environment
from open_spiel.python.pytorch import dqn as dqn_pt
from open_spiel.python.algorithms import dqn
from open_spiel.python.algorithms import random_agent
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
checkpoint_dir = "/tmp/dqn_test"
num_train_episodes = 10000
eval_every = 100

hidden_layers_sizes = [64, 64]
replay_buffer_capacity = int(1e5)
batch_size = 32

# %%
def eval_against_random_bots(env, trained_agents, random_agents, num_episodes):
  """Evaluates `trained_agents` against `random_agents` for `num_episodes`."""
  num_players = len(trained_agents)
  sum_episode_rewards = np.zeros(num_players)
  for player_pos in range(num_players):
    cur_agents = random_agents[:]
    cur_agents[player_pos] = trained_agents[player_pos]
    for _ in range(num_episodes):
      time_step = env.reset()
      episode_rewards = 0
      while not time_step.last():
        player_id = time_step.observations["current_player"]
        if env.is_turn_based:
          agent_output = cur_agents[player_id].step(
              time_step, is_evaluation=True)
          action_list = [agent_output.action]
        else:
          agents_output = [
              agent.step(time_step, is_evaluation=True) for agent in cur_agents
          ]
          action_list = [agent_output.action for agent_output in agents_output]
        time_step = env.step(action_list)
        episode_rewards += time_step.rewards[player_pos]
      sum_episode_rewards[player_pos] += episode_rewards
  return sum_episode_rewards / num_episodes

# %%
def pt_main(checkpoint_dir,
         num_train_episodes,
         eval_every,
         hidden_layers_sizes,
         replay_buffer_capacity,batch_size):
  game = "breakthrough"
  num_players = 2

  env_configs = {"columns": 5, "rows": 5}
  env = rl_environment.Environment(game, **env_configs)
  info_state_size = env.observation_spec()["info_state"][0]
  num_actions = env.action_spec()["num_actions"]

  # random agents for evaluation
  random_agents = [
      random_agent.RandomAgent(player_id=idx, num_actions=num_actions)
      for idx in range(num_players)
  ]


  hidden_layers_sizes = [int(l) for l in hidden_layers_sizes]
  # pylint: disable=g-complex-comprehension
  agents = [
      dqn_pt.DQN(
          player_id=idx,
          state_representation_size=info_state_size,
          num_actions=num_actions,
          hidden_layers_sizes=hidden_layers_sizes,
          replay_buffer_capacity=replay_buffer_capacity,
          batch_size=batch_size) for idx in range(num_players)
  ]
  result = []
  for ep in range(num_train_episodes):
    if (ep + 1) % eval_every == 0:
      r_mean = eval_against_random_bots(env, agents, random_agents, 1000)
      result.append(r_mean)
      print("[%s] Mean episode rewards %s" %(ep + 1, r_mean))

    time_step = env.reset()
    while not time_step.last():
      player_id = time_step.observations["current_player"]
      if env.is_turn_based:
        agent_output = agents[player_id].step(time_step)
        action_list = [agent_output.action]
      else:
        agents_output = [agent.step(time_step) for agent in agents]
        action_list = [agent_output.action for agent_output in agents_output]
      time_step = env.step(action_list)

    # Episode is over, step all agents with final info state.
    for agent in agents:
      agent.step(time_step)
  return result

# %%
result = main(checkpoint_dir,
         num_train_episodes,
         eval_every,
         hidden_layers_sizes,
         replay_buffer_capacity,batch_size)
# Out:
# [100] Mean episode rewards [0.438 0.068]
# [200] Mean episode rewards [0.33  0.036]
# [300] Mean episode rewards [0.218 0.058]
# [400] Mean episode rewards [0.174 0.098]
# [500] Mean episode rewards [ 0.048 -0.034]
# [600] Mean episode rewards [0.178 0.06 ]
# [700] Mean episode rewards [0.106 0.086]
# [800] Mean episode rewards [ 0.27  -0.028]
# [900] Mean episode rewards [0.34  0.066]
# [1000] Mean episode rewards [0.36  0.106]
# [1100] Mean episode rewards [0.348 0.024]
# [1200] Mean episode rewards [0.202 0.016]
# [1300] Mean episode rewards [ 0.504 -0.046]
# [1400] Mean episode rewards [0.776 0.02 ]
# [1500] Mean episode rewards [0.742 0.178]
# [1600] Mean episode rewards [0.728 0.158]
# [1700] Mean episode rewards [0.572 0.332]
# [1800] Mean episode rewards [0.69  0.306]
# [1900] Mean episode rewards [0.846 0.432]
# [2000] Mean episode rewards [0.72  0.426]
# [2100] Mean episode rewards [0.598 0.584]
# [2200] Mean episode rewards [0.588 0.65 ]
# [2300] Mean episode rewards [0.644 0.586]
# [2400] Mean episode rewards [0.45  0.758]
# [2500] Mean episode rewards [0.42  0.676]
# [2600] Mean episode rewards [0.41  0.724]
# [2700] Mean episode rewards [0.432 0.76 ]
# [2800] Mean episode rewards [0.646 0.704]
# [2900] Mean episode rewards [0.664 0.762]
# [3000] Mean episode rewards [0.736 0.756]
# [3100] Mean episode rewards [0.67  0.734]
# [3200] Mean episode rewards [0.814 0.5  ]
# [3300] Mean episode rewards [0.83  0.486]
# [3400] Mean episode rewards [0.924 0.696]
# [3500] Mean episode rewards [0.836 0.798]
# [3600] Mean episode rewards [0.916 0.85 ]
# [3700] Mean episode rewards [0.884 0.734]
# [3800] Mean episode rewards [0.916 0.778]
# [3900] Mean episode rewards [0.924 0.774]
# [4000] Mean episode rewards [0.938 0.816]
# [4100] Mean episode rewards [0.928 0.756]
# [4200] Mean episode rewards [0.924 0.778]
# [4300] Mean episode rewards [0.91 0.88]
# [4400] Mean episode rewards [0.934 0.898]
# [4500] Mean episode rewards [0.95  0.932]
# [4600] Mean episode rewards [0.968 0.894]
# [4700] Mean episode rewards [0.896 0.902]
# [4800] Mean episode rewards [0.952 0.9  ]
# [4900] Mean episode rewards [0.944 0.926]
# [5000] Mean episode rewards [0.944 0.902]
# [5100] Mean episode rewards [0.946 0.914]
# [5200] Mean episode rewards [0.932 0.924]
# [5300] Mean episode rewards [0.908 0.89 ]
# [5400] Mean episode rewards [0.96  0.928]
# [5500] Mean episode rewards [0.948 0.884]
# [5600] Mean episode rewards [0.93  0.906]
# [5700] Mean episode rewards [0.944 0.924]
# [5800] Mean episode rewards [0.976 0.91 ]
# [5900] Mean episode rewards [0.96  0.928]
# [6000] Mean episode rewards [0.964 0.916]
# [6100] Mean episode rewards [0.944 0.928]
# [6200] Mean episode rewards [0.976 0.948]
# [6300] Mean episode rewards [0.968 0.946]
# [6400] Mean episode rewards [0.956 0.944]
# [6500] Mean episode rewards [0.954 0.948]
# [6600] Mean episode rewards [0.938 0.926]
# [6700] Mean episode rewards [0.964 0.93 ]
# [6800] Mean episode rewards [0.95  0.904]
# [6900] Mean episode rewards [0.95 0.92]
# [7000] Mean episode rewards [0.954 0.88 ]
# [7100] Mean episode rewards [0.946 0.924]
# [7200] Mean episode rewards [0.902 0.884]
# [7300] Mean episode rewards [0.934 0.902]
# [7400] Mean episode rewards [0.932 0.944]
# [7500] Mean episode rewards [0.95  0.944]
# [7600] Mean episode rewards [0.964 0.944]
# [7700] Mean episode rewards [0.936 0.93 ]
# [7800] Mean episode rewards [0.946 0.936]
# [7900] Mean episode rewards [0.93  0.932]
# [8000] Mean episode rewards [0.942 0.928]
# [8100] Mean episode rewards [0.898 0.904]
# [8200] Mean episode rewards [0.928 0.91 ]
# [8300] Mean episode rewards [0.924 0.912]
# [8400] Mean episode rewards [0.912 0.908]
# [8500] Mean episode rewards [0.924 0.9  ]
# [8600] Mean episode rewards [0.93 0.91]
# [8700] Mean episode rewards [0.932 0.922]
# [8800] Mean episode rewards [0.906 0.944]
# [8900] Mean episode rewards [0.912 0.892]
# [9000] Mean episode rewards [0.924 0.914]
# [9100] Mean episode rewards [0.906 0.914]
# [9200] Mean episode rewards [0.954 0.922]
# [9300] Mean episode rewards [0.922 0.918]
# [9400] Mean episode rewards [0.948 0.914]
# [9500] Mean episode rewards [0.92  0.856]
# [9600] Mean episode rewards [0.942 0.912]
# [9700] Mean episode rewards [0.93  0.938]
# [9800] Mean episode rewards [0.92  0.944]
# [9900] Mean episode rewards [0.896 0.91 ]
# [10000] Mean episode rewards [0.92  0.886]

# %%
import matplotlib.pyplot as plt

ep = [x for x in range(len(result))]
r_mean0 = [y[0] for y in result]
r_mean1 = [y[1] for y in result]

plt.plot(ep,r_mean0)
plt.plot(ep,r_mean1)

# %%
def tf_main(checkpoint_dir,
         num_train_episodes,
         eval_every,
         hidden_layers_sizes,
         replay_buffer_capacity,batch_size):
  game = "breakthrough"
  num_players = 2

  env_configs = {"columns": 5, "rows": 5}
  env = rl_environment.Environment(game, **env_configs)
  info_state_size = env.observation_spec()["info_state"][0]
  num_actions = env.action_spec()["num_actions"]

  # random agents for evaluation
  random_agents = [
      random_agent.RandomAgent(player_id=idx, num_actions=num_actions)
      for idx in range(num_players)
  ]

  with tf.Session() as sess:
    hidden_layers_sizes = [int(l) for l in hidden_layers_sizes]
    # pylint: disable=g-complex-comprehension
    agents = [
        dqn.DQN(
            session=sess,
            player_id=idx,
            state_representation_size=info_state_size,
            num_actions=num_actions,
            hidden_layers_sizes=hidden_layers_sizes,
            replay_buffer_capacity=replay_buffer_capacity,
            batch_size=batch_size) for idx in range(num_players)
    ]
    saver = tf.train.Saver()
    sess.run(tf.global_variables_initializer())
    
    result_tf = []
    for ep in range(num_train_episodes):
      if (ep + 1) % eval_every == 0:
        r_mean = eval_against_random_bots(env, agents, random_agents, 1000)
        result_tf.append(r_mean)
        print("[%s] Mean episode rewards %s" %(ep + 1, r_mean))

      time_step = env.reset()
      while not time_step.last():
        player_id = time_step.observations["current_player"]
        if env.is_turn_based:
          agent_output = agents[player_id].step(time_step)
          action_list = [agent_output.action]
        else:
          agents_output = [agent.step(time_step) for agent in agents]
          action_list = [agent_output.action for agent_output in agents_output]
        time_step = env.step(action_list)

      # Episode is over, step all agents with final info state.
      for agent in agents:
        agent.step(time_step)
  return result_tf

# %%
result_tf = tf_main(checkpoint_dir,
                    num_train_episodes,
                    eval_every,
                    hidden_layers_sizes,
                    replay_buffer_capacity,batch_size)
# Out:
# Tensor("Max_2:0", shape=(?,), dtype=float32)
# (?, 2) (?, 300)
# (?,)
# Tensor("Max_3:0", shape=(?,), dtype=float32)
# (?, 2) (?, 300)
# (?,)
# [100] Mean episode rewards [0.786 0.14 ]
# [200] Mean episode rewards [ 0.694 -0.022]
# [300] Mean episode rewards [ 0.538 -0.13 ]
# [400] Mean episode rewards [ 0.554 -0.198]
# [500] Mean episode rewards [ 0.526 -0.188]
# [600] Mean episode rewards [ 0.472 -0.28 ]
# [700] Mean episode rewards [ 0.52  -0.248]
# [800] Mean episode rewards [ 0.408 -0.204]
# [900] Mean episode rewards [ 0.346 -0.148]
# [1000] Mean episode rewards [ 0.43 -0.11]
# [1100] Mean episode rewards [ 0.306 -0.088]
# [1200] Mean episode rewards [ 0.386 -0.112]
# [1300] Mean episode rewards [ 0.362 -0.034]
# [1400] Mean episode rewards [ 0.348 -0.102]
# [1500] Mean episode rewards [ 0.394 -0.066]
# [1600] Mean episode rewards [0.358 0.002]
# [1700] Mean episode rewards [ 0.482 -0.004]
# [1800] Mean episode rewards [ 0.468 -0.066]
# [1900] Mean episode rewards [ 0.63  -0.018]
# [2000] Mean episode rewards [0.584 0.072]
# [2100] Mean episode rewards [0.622 0.182]
# [2200] Mean episode rewards [0.622 0.198]
# [2300] Mean episode rewards [0.61 0.38]
# [2400] Mean episode rewards [0.66  0.534]
# [2500] Mean episode rewards [0.662 0.69 ]
# [2600] Mean episode rewards [0.68  0.698]
# [2700] Mean episode rewards [0.662 0.77 ]
# [2800] Mean episode rewards [0.662 0.796]
# [2900] Mean episode rewards [0.666 0.752]
# [3000] Mean episode rewards [0.664 0.764]
# [3100] Mean episode rewards [0.694 0.746]
# [3200] Mean episode rewards [0.614 0.728]
# [3300] Mean episode rewards [0.678 0.688]
# [3400] Mean episode rewards [0.752 0.698]
# [3500] Mean episode rewards [0.83 0.66]
# [3600] Mean episode rewards [0.84 0.74]
# [3700] Mean episode rewards [0.844 0.824]
# [3800] Mean episode rewards [0.836 0.806]
# [3900] Mean episode rewards [0.852 0.786]
# [4000] Mean episode rewards [0.854 0.816]
# [4100] Mean episode rewards [0.866 0.794]
# [4200] Mean episode rewards [0.882 0.836]
# [4300] Mean episode rewards [0.928 0.834]
# [4400] Mean episode rewards [0.938 0.902]
# [4500] Mean episode rewards [0.888 0.88 ]
# [4600] Mean episode rewards [0.9  0.87]
# [4700] Mean episode rewards [0.922 0.868]
# [4800] Mean episode rewards [0.908 0.896]
# [4900] Mean episode rewards [0.932 0.896]
# [5000] Mean episode rewards [0.938 0.904]
# [5100] Mean episode rewards [0.944 0.904]
# [5200] Mean episode rewards [0.914 0.932]
# [5300] Mean episode rewards [0.906 0.91 ]
# [5400] Mean episode rewards [0.914 0.918]
# [5500] Mean episode rewards [0.868 0.922]
# [5600] Mean episode rewards [0.884 0.918]
# [5700] Mean episode rewards [0.918 0.888]
# [5800] Mean episode rewards [0.922 0.93 ]
# [5900] Mean episode rewards [0.914 0.904]
# [6000] Mean episode rewards [0.916 0.892]
# [6100] Mean episode rewards [0.904 0.876]
# [6200] Mean episode rewards [0.908 0.892]
# [6300] Mean episode rewards [0.882 0.892]
# [6400] Mean episode rewards [0.906 0.922]
# [6500] Mean episode rewards [0.912 0.938]
# [6600] Mean episode rewards [0.87  0.938]
# [6700] Mean episode rewards [0.906 0.92 ]
# [6800] Mean episode rewards [0.916 0.914]
# [6900] Mean episode rewards [0.918 0.93 ]
# [7000] Mean episode rewards [0.908 0.918]
# [7100] Mean episode rewards [0.92 0.91]
# [7200] Mean episode rewards [0.914 0.924]
# [7300] Mean episode rewards [0.91  0.924]
# [7400] Mean episode rewards [0.91  0.914]
# [7500] Mean episode rewards [0.926 0.934]
# [7600] Mean episode rewards [0.908 0.928]
# [7700] Mean episode rewards [0.912 0.886]
# [7800] Mean episode rewards [0.866 0.868]
# [7900] Mean episode rewards [0.88  0.918]
# [8000] Mean episode rewards [0.872 0.914]
# [8100] Mean episode rewards [0.88 0.95]
# [8200] Mean episode rewards [0.874 0.912]
# [8300] Mean episode rewards [0.896 0.898]
# [8400] Mean episode rewards [0.882 0.916]
# [8500] Mean episode rewards [0.896 0.936]
# [8600] Mean episode rewards [0.91  0.922]
# [8700] Mean episode rewards [0.87  0.904]
# [8800] Mean episode rewards [0.938 0.928]
# [8900] Mean episode rewards [0.92 0.93]
# [9000] Mean episode rewards [0.92 0.92]
# [9100] Mean episode rewards [0.928 0.91 ]
# [9200] Mean episode rewards [0.93 0.91]
# [9300] Mean episode rewards [0.928 0.872]
# [9400] Mean episode rewards [0.922 0.894]
# [9500] Mean episode rewards [0.902 0.93 ]
# [9600] Mean episode rewards [0.906 0.916]
# [9700] Mean episode rewards [0.918 0.928]
# [9800] Mean episode rewards [0.926 0.898]
# [9900] Mean episode rewards [0.94  0.908]
# [10000] Mean episode rewards [0.958 0.908]

# %%
ep = [x for x in range(len(result_tf))]
r_mean2 = [y[0] for y in result_tf]
r_mean3 = [y[1] for y in result_tf]

plt.plot(ep,r_mean2)
plt.plot(ep,r_mean3)

# %%
plt.plot(ep,r_mean0)
plt.plot(ep,r_mean1)
plt.plot(ep,r_mean2)
plt.plot(ep,r_mean3)
plt.show()
